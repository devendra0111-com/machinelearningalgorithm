# %%
def welcome():
    
    for i in range (0,15):
        print('*\t',end = '')
    print()

    print('*', end = ' ')
    for i in range(0,14):
        print('\t',end = '')
    print('*')

    print('*',end ='') 
    for i in range (0,14):
        print('\t',end ='')
    print('*')

    print('*',end ='')
    for i in range(0,14):
        print('\t',end ='')
    print('*')

    print('*',end ='')
    for i in range(0,14):
        print('\t',end ='')
    print('*')

    print('*',end ='')
    for i in range(0,7):
        print('\t',end ='')
    print('WELCOME',end = '')
    for i in range(0,7):
        print('\t',end ='')
    print('*')

    print('*', end = ' ')
    for i in range(0,14):
        print('\t',end = '')
    print('*')

    print('*',end ='') 
    for i in range (0,14):
        print('\t',end ='')
    print('*')

    print('*',end ='')
    for i in range(0,14):
        print('\t',end ='')
    print('*')

    print('*',end ='')
    for i in range(0,14):
        print('\t',end ='')
    print('*')

    for i in range(0,15):
        print('*\t',end ='')
    print()

    input('enter any key value to start:')
    print('\n'*100)
    
    
    
    
    
    
    
    
    
    
    def main_menu():
        print('1.Rock Paper And Scissors \n2.Tic Tac Toe \n3. EXIT')
        chc = int(input('enter game value:'))
        if chc == 1:
            Rock Paper Scissors_menu()
        elif chc == 2:
            TTT_menu()
        elif chc == 3:
            exit()
        else:
            print('Invalid Game')
            main_menu()
            
    def Rock Paper Scissors_menu():
# Out:
# *	*	*	*	*	*	*	*	*	*	*	*	*	*	*
# * 														*
# *														*
# *														*
# *														*
# *							WELCOME							*
# * 														*
# *														*
# *														*
# *														*
# *	*	*	*	*	*	*	*	*	*	*	*	*	*	*
# enter any key value to start:5
# 1.Rock Paper And Scissors
# 2.Tic Tac Toe
# 3. EXIT
# enter game value:4
# Invalid Game
